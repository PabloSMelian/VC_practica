# %% [markdown]
# Paquetes necesarios

# %%
import cv2  
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Inicializaciones

# %%
#Dimensiones de la imagen a crear
ancho = 200
alto = 300

# %% [markdown]
# Imagen en grises

# %%
#Crea una imagen de un único plano, que se interpreta como nivel de gris (0 negro, 255 blanco)
gris_img = np.zeros((ancho,alto,1), dtype = np.uint8)
#Muestra dimensiones de la imagen creada
print(gris_img.shape)
# Out:
# (200, 300, 1)

# %% [markdown]
# Muestra imagen con imshow (OpenCV) en ventana independiente

# %%
#Muestra la imagen (negra al inicializarse a 0) con las utilidades de OpenCV en una ventana independiente
cv2.imshow('Imagen', gris_img)
cv2.imshow('Imagen2', gris_img)

cv2.waitKey(-1) # Se detiene hasta pulsar tecla (>0 milisegundos)
cv2.destroyAllWindows() # Destruye todas las ventanas
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\pablo\Desktop\uni\jajant\VC_P1.ipynb Cell 8 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/pablo/Desktop/uni/jajant/VC_P1.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> cv2.imshow('Imagen', gris_img)
#       <a href='vscode-notebook-cell:/c%3A/Users/pablo/Desktop/uni/jajant/VC_P1.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> cv2.imshow('Imagen2', gris_img)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pablo/Desktop/uni/jajant/VC_P1.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a> cv2.waitKey(-1) # Se detiene hasta pulsar tecla (>0 milisegundos)
#       <a href='vscode-notebook-cell:/c%3A/Users/pablo/Desktop/uni/jajant/VC_P1.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a> cv2.destroyAllWindows() # Destruye todas las ventanas
#
# KeyboardInterrupt:

# %% [markdown]
# Muestra imagen con matplotlib

# %%
#Muestra la imagen con matplotlib, aparece integrada en el cuaderno
#Es necesario especificar que el mapa de color usado es de grises
#plt.imshow(gris_img, cmap='gray')
#plt.imshow(gris_img)
#plt.show()

#replicar una imagen de gris creando una imagen gris pero con tres planos (RGB)
img2 = cv2.merge((gris_img,gris_img,gris_img))
plt.imshow(img2)
plt.show()

# %%
#Modifica un par de zonas rectangulares de la imagen
gris_img[:] = 0
gris_img[10:20,0:20,0] = 255 #Especifica el canal 0
gris_img[110:220,0:20,0] = 28 #
#gris_img[50:70,40:60] = 255 #realmente no es necesario con un único plano

#Muestra la imagen con matplotlib
#Es necesario especificar que el mapa de color usado es de grises
plt.imshow(gris_img, cmap='gray')
plt.show()

# %% [markdown]
# Imagen con tono de gris aleatorio

# %%
#Crea imagen con un único plano (gris)
gris_img = np.random.randint(255, size=(ancho,alto, 1))
#Muestra dimensiones
print(gris_img.shape)
#Visualiza
plt.imshow(gris_img, cmap='gray') #Visualiza con mapa de color gris
plt.show()
# Out:
# (200, 300, 1)

# %% [markdown]
# Asignamos valor a los píxeles de una zona concreta

# %%
#Modifica la primera mitad de la imagen, asignando 255, es decir blanco
gris_img[0:int(alto/2),:,:] = 255
#Visualiza con mapa de color gris
plt.imshow(gris_img, cmap='gray') #Te animo a probar a eliminar la especificación del mapa de color
plt.show()

# %% [markdown]
# TAREA: Crea una imagen, p.e. 800x800, con la textura del tablero de ajedrez

# %%
table_size=400
box_size=table_size//8
table_img = np.zeros((table_size,table_size,1), dtype = np.uint8)
box_1_color=255
box_2_color=0



for line in range(8):
    for column in range(8):
        x0= column*box_size
        y0= line*box_size
        x1=x0+box_size
        y1=y0+box_size
        color= box_1_color if (line+column)%2==0 else box_2_color
        table_img[x0:x1,y0:y1,0]=color

plt.imshow(table_img, cmap='gray') #Te animo a probar a eliminar la especificación del mapa de color
plt.show()

# %% [markdown]
# Imagen en color

# %%
#Crea una imagen con tres planos
color_img = np.zeros((200,200,3), dtype = np.uint8)
#Dimensiones
print(color_img.shape)
#Visualiza sin especificar el mapa de color gris
plt.imshow(color_img) 
plt.show()
# Out:
# (200, 200, 3)

# %%
#Modifica el primer plano de color (Rojo, ya que es RGB)
#color_img[:,:,0] = 255 
#color_img[:,:,1] = 200 #Prueba otras combinaciones
color_img[:,:,2] = 100 
plt.imshow(color_img) 
plt.show()

# %% [markdown]
# TAREA: Crear una imagen estilo Mondrian (un ejemplo https://www3.gobiernodecanarias.org/medusa/ecoescuela/sa/2017/04/17/descubriendo-a-mondrian/ )

# %%
color_img = np.zeros((200,200,3), dtype = np.uint8)

#Rectángulo relleno
cv2.rectangle(color_img,(0,0),(60,40),(255,255,255),-1)
cv2.rectangle(color_img,(65,0),(95,40),(255,0,0),-1)
cv2.rectangle(color_img,(100,0),(200,40),(0,0,255),-1)
cv2.rectangle(color_img,(0,45),(60,100),(255,255,255),-1)
cv2.rectangle(color_img,(65,45),(95,100),(0,0,255),-1)
cv2.rectangle(color_img,(100,45),(200,100),(0,0,255),-1)
cv2.rectangle(color_img,(0,105),(95,125),(255,255,255),-1)
cv2.rectangle(color_img,(100,105),(175,125),(255,0,0),-1)
cv2.rectangle(color_img,(180,105),(200,125),(255,255,255),-1)
cv2.rectangle(color_img,(0,130),(175,150),(0,0,255),-1)
cv2.rectangle(color_img,(180,130),(200,200),(255,255,255),-1)
cv2.rectangle(color_img,(0,155),(60,200),(0,0,255),-1)
cv2.rectangle(color_img,(65,155),(175,200),(255,0,0),-1)
#Visualiza sin especificar el mapa de color gris
plt.imshow(color_img) 
plt.show()


#Salva la imagen resultante a disco
cv2.imwrite('imagen.jpg', color_img)
# Out:
# True

# %% [markdown]
# Funciones de dibujo.
# OpenCV dispone de distintas funciones específicas para dibujar formas básicas (más información https://docs.opencv.org/4.x/dc/da5/tutorial_py_drawing_functions.html )

# %%
#Crea una imagen con tres planos
color_img = np.zeros((200,200,3), dtype = np.uint8)

#Línea roja vertical de grosor 3
cv2.line(color_img,(int(ancho/2),0),(int(ancho/2),alto),(255,0,0),3)
#Rectángulo con grosor 2
cv2.rectangle(color_img,(10,10),(ancho-10,int(alto/2)),(0,255,0),2)
#Rectángulo relleno
cv2.rectangle(color_img,(20,20),(60,40),(0,255,0),-1)
#Círculo de radio 15 relleno
cv2.circle(color_img,(ancho-60,30), 15, (0,0,255), -1)
#Visualiza sin especificar el mapa de color gris
plt.imshow(color_img) 
plt.show()


#Salva la imagen resultante a disco
cv2.imwrite('imagen.jpg', color_img)
# Out:
# True

# %% [markdown]
# TAREA: Resuelve una de las tareas previas (a elegir) con las funciones de dibujo de OpenCV  :)

# %% [markdown]
# Abrir imagen almacenada en disco

# %%
#Carga imagen desde disco
img = cv2.imread('logo_ulpgc_vertical_acronimo_mancheta_azul.png') 
#Dimensiones
print(img.shape)
#Muestra
plt.imshow(img) 
plt.show()

#OpenCV lee las imágenes de disco en formato BGR, por lo que convertimos para visualizr RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb) 
plt.show()

#Fuerza lectura en grises
img = cv2.imread('logo_ulpgc_vertical_acronimo_mancheta_azul.png', cv2.IMREAD_GRAYSCALE) 
plt.imshow(img, cmap='gray') 
plt.show()

# %% [markdown]
# Abre un archivo de vídeo

# %%
vid = cv2.VideoCapture('Ayagaures_vibe_result.mp4') #Busca n vídeo propio
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:  
        # Muestra fotograma
        cv2.imshow('Vid', frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(1000) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Muestra entrada de la cámara

# %%
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()
  
    if ret:  
        # Muestra fotograma
        cv2.imshow('Vid', frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Separa los tres planos de la imagen captada por la webcam

# %%
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:
        #Separamos canales
        b = frame[:,:,0]
        g = frame[:,:,1]
        r = frame[:,:,2]
        #Dimensiones
        h, w, c = frame.shape

        #Concateamos en horizontal los tres planos del fotograma
        collage = np.hstack((r, g, b))
    
        # Muestra fotograma redimensionando a la mitad para que quepa en pantalla
        cv2.imshow('Cam3', cv2.resize(collage, (int(w*1.5),int(h/2)),cv2.INTER_NEAREST))
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# TAREA: Modifica de alguna forma los valores de un plano de la imagen

# %%
vid = cv2.VideoCapture(0)

#Dimensiones de la cámara
w = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))

#Fuerzo a mitad de resolución para ocupar menos pantalla
vid.set(cv2.CAP_PROP_FRAME_WIDTH, w) #En Mac no reacciona a estos comandos
vid.set(cv2.CAP_PROP_FRAME_HEIGHT, h)

#Imagen conjunta 2x original
collage = np.zeros((h,w,3), dtype = np.uint8)
tl = collage[0:h,0:w]

while True:      
    # fotograma a fotograma
    ret, frameIN = vid.read()

    #Menor tamaño
    frame = cv2.resize(frameIN, (int(w),int(h)),cv2.INTER_NEAREST)

    if ret:
        #Separamos canales
        r = frame[:,:,2]
        g = frame[:,:,1]
        b = frame[:,:,0]

        #Jugamos
        tl[:,:,0] = 255-b
        tl[:,:,1] = 255-g
        tl[:,:,2] = 255-r
    
        # Muestra composicion
        cv2.imshow('Cam', collage)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Evento de ratón para mostrar el valor RGB del píxel

# %%
# Función que trata eventos de ratón 
def mouse_events(event, x, y, flags, params):
    global px, py, R, G, B
    px = -1
    # Movimiento del puntero     
    if event==cv2.EVENT_MOUSEMOVE:
        #Valores del píxel
        B = frame[y, x, 0]
        G = frame[y, x, 1]
        R = frame[y, x, 2]  

        px = x
        py = y

# %%
vid = cv2.VideoCapture(0)

# Tipografía para mostrar texto
font = cv2.FONT_HERSHEY_SIMPLEX
  
lanzado = 0
px = -1
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret: 
        # Activa em manejador en el primer fotograma
        if lanzado == 0:
            # Muestra fotograma
            cv2.imshow('Cam', frame)   
            # Define el nombre del manejador del evento
            cv2.setMouseCallback('Cam', mouse_events)
            lanzado = 1
            
        # Muestra valores RGB intentando centrar en el puntero
        if px > -1:
            cv2.putText(frame, '{}'.format(R), (px-45,py-5), font, 0.5, (0, 0, 255), 1)
            cv2.putText(frame, '     {}'.format(G), (px-54,py-5), font, 0.5, (0, 255, 0), 1)
            cv2.putText(frame, '         {}'.format(B), (px-54,py-5), font, 0.5, (255, 0, 0), 1)
            
        cv2.imshow('Cam', frame)   
        
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\pablo\Desktop\uni\jajant\VC_P1.ipynb Cell 36 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/pablo/Desktop/uni/jajant/VC_P1.ipynb#X50sZmlsZQ%3D%3D?line=15'>16</a>     cv2.imshow('Cam', frame)
#      <a href='vscode-notebook-cell:/c%3A/Users/pablo/Desktop/uni/jajant/VC_P1.ipynb#X50sZmlsZQ%3D%3D?line=16'>17</a>     # Define el nombre del manejador del evento
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pablo/Desktop/uni/jajant/VC_P1.ipynb#X50sZmlsZQ%3D%3D?line=17'>18</a>     cv2.setMouseCallback('Cam', mouse_events)
#      <a href='vscode-notebook-cell:/c%3A/Users/pablo/Desktop/uni/jajant/VC_P1.ipynb#X50sZmlsZQ%3D%3D?line=18'>19</a>     lanzado = 1
#      <a href='vscode-notebook-cell:/c%3A/Users/pablo/Desktop/uni/jajant/VC_P1.ipynb#X50sZmlsZQ%3D%3D?line=20'>21</a> # Muestra valores RGB intentando centrar en el puntero
#
# NameError: name 'mouse_events' is not defined
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# TAREA:
# Pintar círculos en las posiciones del píxel más claro y oscuro de la imagen
# ¿Si quisieras hacerlo sobre la zona 8x8 más clara/oscura?

# %%
cap = cv2.VideoCapture(0)  # 0 representa la cámara predeterminada

while True:
    # Capturar un fotograma de la cámara
    ret, frame = cap.read()

    # Comprueba si la captura fue exitosa
    if not ret:
        break

    # Encuentra la posición del píxel más oscuro en la imagen
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))
    center_x_dark, center_y_dark = min_loc  # Posición del píxel más oscuro

    # Dibujar un círculo en la posición del píxel más oscuro
    radius = 10  # Radio del círculo
    color = (0, 0, 255)  # Color en formato BGR (Rojo en este caso)
    thickness = 2  # Grosor de la línea del círculo
    cv2.circle(frame, (center_x_dark, center_y_dark), radius, color, thickness)

    center_x_clear, center_y_clear = max_loc  # Posición del píxel más oscuro

    # Dibujar un círculo en la posición del píxel más oscuro
    radius = 10  # Radio del círculo
    color = (0, 255, 0)  # Color en formato BGR (Verde en este caso)
    thickness = 2  # Grosor de la línea del círculo
    cv2.circle(frame, (center_x_clear, center_y_clear), radius, color, thickness)

    # Mostrar la imagen con el círculo
    cv2.imshow('Cámara con Círculo en Píxel Más Oscuro y otro en el mas claro', frame)

    # Esperar a que se presione la tecla 'q' para salir
    if cv2.waitKey(20) == 27:
        break
  
# Liberar la cámara y cerrar la ventana
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# Pop art
# Salida de la webcam "inspirada" en Andy Warhol

# %%
vid = cv2.VideoCapture(0)

#Dimensiones de la cámara
w = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))

#Fuerzo a mitad de resolución para ocupar menos pantalla
w=int(w/2)
h=int(h/2)
vid.set(cv2.CAP_PROP_FRAME_WIDTH, w) #En Mac no reacciona a estos comandos
vid.set(cv2.CAP_PROP_FRAME_HEIGHT, h)

#Imagen conjunta 2x original
collage = np.zeros((h*2,w*2,3), dtype = np.uint8)
tl = collage[0:h,0:w]
tr = collage[0:h,w:w+w]
bl = collage[h:h+h,0:w]
br = collage[h:h+h,w:w+w]

while True:      
    # fotograma a fotograma
    ret, frameIN = vid.read()

    #Menor tamaño
    frame = cv2.resize(frameIN, (int(w),int(h)),cv2.INTER_NEAREST)

    if ret:
        #Separamos canales
        r = frame[:,:,2]
        g = frame[:,:,1]
        b = frame[:,:,0]

        #Jugamos
        tl[:,:,0] = b
        tl[:,:,1] = g
        tl[:,:,2] = r

        tr[:,:,0] = 255 - r
        tr[:,:,1] = g
        tr[:,:,2] = b
        
        bl[:,:,0] = r
        bl[:,:,1] = 255 - b
        bl[:,:,2] = g

        br[:,:,0] = b
        br[:,:,1] = g
        br[:,:,2] = 255 - r
    
        # Muestra composicion
        cv2.imshow('Cam', collage)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Transformando la imagen capturada en una colección de círculos, cuyo radio depende de la intensidad promedio de la zona

# %%
vid = cv2.VideoCapture(0)

ncells = 10
off = int(ncells/2)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:
        #Dimensiones originales
        h, w, c = frame.shape
        #Redimensiono
        down_frame = cv2.resize(frame, (int(w/ncells),int(h/ncells)),cv2.INTER_NEAREST)
        #Dimensiones reducidas
        h2, w2, c2 = down_frame.shape

        #Separamos canales
        r = down_frame[:,:,0]
        g = down_frame[:,:,1]
        b = down_frame[:,:,2]

        # Creamos imagen negra
        gris_up_frame = np.zeros((h2*ncells,w2*ncells,1), dtype = np.uint8)

        for y in range(0,h2):
            for x in range(0,w2):
                # La suma de los valores RGB define el radio del círculo
                rad = int ( (r[y,x] + g[y,x] + b[y,x])/(ncells*3*2))
                cv2.circle(gris_up_frame,(x*ncells+off, y*ncells + off), rad, (255,255,255), -1)

    
        # Muestra fotograma resultante
        cv2.imshow('Cam', gris_up_frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# TAREA: Haz tu propuesta pop art

# %%
vid = cv2.VideoCapture(0)

ncells = 10
off = int(ncells/2)
  
while True:      
    ret, frame = vid.read()

    if ret:
        h, w, c = frame.shape
        down_frame = cv2.resize(frame, (int(w/ncells), int(h/ncells)), cv2.INTER_NEAREST)
        h2, w2, c2 = down_frame.shape

        r = down_frame[:,:,0]
        g = down_frame[:,:,1]
        b = down_frame[:,:,2]

        gris_up_frame = np.zeros((h2*ncells, w2*ncells, 1), dtype=np.uint8)

        for y in range(0, h2):
            for x in range(0, w2):
                # La suma de los valores RGB define el tamaño del cuadrado
                size = int((r[y, x] + g[y, x] + b[y, x]) / (ncells * 3 * 2))
                x1, y1 = x*ncells+off-size, y*ncells+off-size
                x2, y2 = x*ncells+off+size, y*ncells+off+size
                cv2.rectangle(gris_up_frame, (x1, y1), (x2, y2), (255, 255, 255), -1)

        cv2.imshow('Cam', gris_up_frame)
    
    if cv2.waitKey(20) == 27:
        break
  
vid.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\pablo\AppData\Local\Temp\ipykernel_14512\2992784828.py:23: RuntimeWarning: overflow encountered in scalar add
#   size = int((r[y, x] + g[y, x] + b[y, x]) / (ncells * 3 * 2))
